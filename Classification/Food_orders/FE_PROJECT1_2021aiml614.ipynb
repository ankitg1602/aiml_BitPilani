# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter
import matplotlib.ticker as mtick
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

import statsmodels.api as sm
import warnings
warnings.filterwarnings('ignore')
plt.style.use('seaborn')
# %matplotlib inline

# set default plot size
plt.rcParams["figure.figsize"] = (15,8)

# %%
# os.chir("C:\Users\ankit\Desktop\ankit_aiml")
df = pd.read_excel("Food Orders.xlsx")
df.head()
# Out:
#       ID  Provider             DateTime  Distance     Status Cost PromoCode  \
# 0    1.0       NaN  1-July-2020 8.38 PM       3.0  Delivered  300       PRO
# 1    2.0       NaN  1-July-2020 8.38 AM       3.0  Delivered  100        BF
# 2    3.0       NaN  1-July-2020 9.00 PM       6.0  Cancelled  250       PRO
# 3    4.0       NaN  1-July-2020 7.30 PM       4.0  Delivered  550       PRO
# 4  423.0       NaN  1-July-2020 8.38 PM       3.0  Cancelled  125       PRO
#
#          Delivery Time  Discount  Paid amount  ... Delivery charges  \
# 0  1-July-2020 9.38 PM      50.0          NaN  ...               20
# 1  1-July-2020 8.58 AM       NaN          NaN  ...               20
# 2  1-July-2020 9.30 PM      25.0          NaN  ...               25
# 3  1-July-2020 9.05 PM       NaN          NaN  ...               25
# 4  1-July-2020 7.38 PM       NaN          NaN  ...               20
#
#   Surge charges Packaging charges ST  Tip  PureVeg             Items  \
# 0           NaN                10  5  NaN        Y       PANEER;ROTI
# 1           NaN                10  5  5.0        N  DAL;CHICKEN;ROTI
# 2            10                10  5  5.0        Y       MIXVEG;RICE
# 3            10                10  5  NaN        N   CHICKEN;BIRYANI
# 4           NaN                10  5  NaN        Y          DAL;ROTI
#
#   Membership Type Rating
# 0       BING  VEG    2.0
# 1       BONG  MIX    4.0
# 2       BING  VEG    0.0
# 3         NO  MIX    1.0
# 4         NO  VEG    1.0
#
# [5 rows x 21 columns]

# %% [markdown]
# # check basic features and data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 58 non-null     float64
#  1   Provider           0 non-null      float64
#  2   DateTime           60 non-null     object
#  3   Distance           59 non-null     float64
#  4   Status             59 non-null     object
#  5   Cost               60 non-null     object
#  6   PromoCode          36 non-null     object
#  7   Delivery Time      59 non-null     object
#  8   Discount           24 non-null     float64
#  9   Paid amount        1 non-null      float64
#  10  Payment mode       59 non-null     object
#  11  Delivery charges   60 non-null     object
#  12  Surge charges      28 non-null     object
#  13  Packaging charges  60 non-null     object
#  14  ST                 60 non-null     object
#  15  Tip                24 non-null     float64
#  16  PureVeg            59 non-null     object
#  17  Items              59 non-null     object
#  18  Membership         59 non-null     object
#  19  Type               59 non-null     object
#  20  Rating             57 non-null     float64
# dtypes: float64(7), object(14)
# memory usage: 10.0+ KB

# %% [markdown]
# above data contain both categorical and numercial data types

# %%
# check no. of records
len(df)
# Out:
# 60

# %% [markdown]
# # Data Cleaning

# %%
# check for doublications
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15     True
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54     True
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# dtype: bool

# %%
#Count duplicate on a column
df.ID.duplicated().sum()
# Out:
# 3

# %%
#Count duplicate in a DataFrame
df.duplicated().sum()
# Out:
# 2

# %%
#Count duplicate on certain columns
# df.duplicated(subset=['Survived', 'Pclass', 'Sex']).sum()

#Exact duplicate rows
df.loc[df.duplicated(), :]
# Out:
#       ID  Provider             DateTime  Distance     Status Cost PromoCode  \
# 15   5.0       NaN  1-July-2020 8.38 PM       3.0  Cancelled  125       PRO
# 54  11.0       NaN  2-July-2020 8.38 PM       3.0  Delivered  500       NaN
#
#           Delivery Time  Discount  Paid amount  ... Delivery charges  \
# 15  1-July-2020 8.38 PM       NaN          NaN  ...               20
# 54  2-July-2020 9.38 PM      50.0          NaN  ...               20
#
#    Surge charges Packaging charges ST Tip  PureVeg        Items Membership  \
# 15           NaN                10  5 NaN        Y     DAL;ROTI         NO
# 54           NaN                10  5 NaN        Y  PANEER;ROTI       BING
#
#    Type Rating
# 15  VEG    1.0
# 54  VEG    4.0
#
# [2 rows x 21 columns]

# %%
#
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 0 to 59
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 56 non-null     float64
#  1   Provider           0 non-null      float64
#  2   DateTime           58 non-null     object
#  3   Distance           57 non-null     float64
#  4   Status             57 non-null     object
#  5   Cost               58 non-null     object
#  6   PromoCode          35 non-null     object
#  7   Delivery Time      57 non-null     object
#  8   Discount           23 non-null     float64
#  9   Paid amount        1 non-null      float64
#  10  Payment mode       57 non-null     object
#  11  Delivery charges   58 non-null     object
#  12  Surge charges      28 non-null     object
#  13  Packaging charges  58 non-null     object
#  14  ST                 58 non-null     object
#  15  Tip                24 non-null     float64
#  16  PureVeg            57 non-null     object
#  17  Items              57 non-null     object
#  18  Membership         57 non-null     object
#  19  Type               57 non-null     object
#  20  Rating             55 non-null     float64
# dtypes: float64(7), object(14)
# memory usage: 10.0+ KB

# %%
df.drop([23,25])
# Out:
#        ID  Provider             DateTime  Distance     Status Cost PromoCode  \
# 0     1.0       NaN  1-July-2020 8.38 PM       3.0  Delivered  300       PRO
# 1     2.0       NaN  1-July-2020 8.38 AM       3.0  Delivered  100        BF
# 2     3.0       NaN  1-July-2020 9.00 PM       6.0  Cancelled  250       PRO
# 3     4.0       NaN  1-July-2020 7.30 PM       4.0  Delivered  550       PRO
# 4   423.0       NaN  1-July-2020 8.38 PM       3.0  Cancelled  125       PRO
# 5     5.0       NaN  1-July-2020 8.38 PM       3.0  Cancelled  125       PRO
# 6     6.0       NaN  1-July-2020 7.38 PM       3.0  Delivered  280       PRO
# 7     7.0       NaN  1-July-2020 9.38 AM       3.0  Delivered  120        BF
# 8     8.0       NaN  1-July-2020 8.00 PM       6.0  Cancelled  230       PRO
# 9     9.0       NaN  1-July-2020 7.30 PM       4.0  Delivered  450       PRO
# 10   10.0       NaN  1-July-2020 7.38 PM       3.0  Cancelled  150       PRO
# 11   11.0       NaN  2-July-2020 8.38 PM       3.0  Delivered  500       NaN
# 12   12.0       NaN  2-July-2020 8.38 AM       3.0  Delivered  400       NaN
# 13   13.0       NaN  2-July-2020 9.00 PM       6.0  Cancelled  300       NaN
# 14   14.0       NaN  2-July-2020 7.30 PM       4.0  Delivered  200       NaN
# 16   15.0       NaN  2-July-2020 7.38 PM       3.0  Cancelled  500       NaN
# 17   16.0       NaN  2-July-2020 7.38 PM       3.0  Delivered  400       NaN
# 18    NaN       NaN  2-July-2020 9.38 AM       3.0  Delivered  300       NaN
# 19   17.0       NaN  2-July-2020 9.38 AM       3.0  Delivered  300       NaN
# 20   18.0       NaN  2-July-2020 8.00 PM       6.0  Cancelled  200       NaN
# 21   19.0       NaN  2-July-2020 7.30 PM       4.0  Delivered  100       NaN
# 22   20.0       NaN  2-July-2020 7.38 PM       3.0  Cancelled  100       NaN
# 24   21.0       NaN  3-July-2020 8.38 PM       3.0  Delivered  300       PRO
# 26   23.0       NaN  3-July-2020 9.00 PM       6.0  Cancelled  250       PRO
# 27   24.0       NaN  3-July-2020 7.30 PM       4.0  Delivered  550       PRO
# 28   25.0       NaN  3-July-2020 8.38 PM       3.0  Cancelled  125       PRO
# 29   26.0       NaN  3-July-2020 7.38 PM       3.0  Delivered  280       PRO
# 30   27.0       NaN  3-July-2020 9.38 AM       3.0  Delivered  120        BF
# 31   28.0       NaN  3-July-2020 8.00 PM       6.0  Cancelled  230       PRO
# 32   29.0       NaN  3-July-2020 7.30 PM       4.0  Delivered  450       PRO
# 33   30.0       NaN  3-July-2020 7.38 PM       3.0  Cancelled  150       PRO
# 34   31.0       NaN  4-July-2020 8.38 PM       3.0  Delivered  500       NaN
# 35  310.0       NaN  4-July-2020 8.38 PM       3.0  Delivered  500       NaN
# 36   32.0       NaN  4-July-2020 8.38 AM       3.0  Delivered  400       NaN
# 37   33.0       NaN  4-July-2020 9.00 PM       6.0  Cancelled  300       NaN
# 38   34.0       NaN  4-July-2020 7.30 PM       4.0  Delivered  200       NaN
# 39   35.0       NaN  4-July-2020 7.38 PM       3.0  Cancelled  500       NaN
# 40   36.0       NaN  4-July-2020 7.38 PM       3.0  Delivered  400       NaN
# 41   37.0       NaN  4-July-2020 9.38 AM       3.0  Delivered  300       NaN
# 42   56.0       NaN  4-July-2020 9.38 AM       3.0  Delivered  300       NaN
# 43   38.0       NaN  4-July-2020 8.00 PM       6.0  Cancelled  200       NaN
# 44   39.0       NaN  4-July-2020 7.30 PM       4.0  Delivered  100       NaN
# 45   40.0       NaN  4-July-2020 7.38 PM       3.0  Cancelled  100       NaN
# 46  467.0       NaN  5-July-2020 8.38 PM       3.0  Delivered  400       PRO
# 47   41.0       NaN  5-July-2020 8.38 PM       3.0  Delivered  400       PRO
# 48   42.0       NaN  5-July-2020 8.38 AM       3.0  Delivered  200        BF
# 49   43.0       NaN  5-July-2020 9.00 PM       6.0  Cancelled  350       PRO
# 50   44.0       NaN  5-July-2020 7.30 PM       4.0  Delivered  600       PRO
# 51   45.0       NaN  5-July-2020 8.38 PM       3.0  Cancelled  225       PRO
# 52   46.0       NaN  5-July-2020 7.38 PM       3.0  Delivered  380       PRO
# 53   47.0       NaN  5-July-2020 9.38 AM       3.0  Delivered  220        BF
# 55  456.0       NaN  5-July-2020 9.38 AM       3.0  Delivered  220        BF
# 56   48.0       NaN  5-July-2020 8.00 PM       6.0  Cancelled  330       PRO
# 57   49.0       NaN  5-July-2020 7.30 PM       4.0  Delivered  450       PRO
# 58   50.0       NaN  5-July-2020 7.38 PM       3.0  Cancelled  250       PRO
# 59   51.0       NaN  5-July-2020 7.38 PM      -2.0  Cancelled  250       PRO
#
#            Delivery Time  Discount  Paid amount  ... Delivery charges  \
# 0    1-July-2020 9.38 PM      50.0          NaN  ...               20
# 1    1-July-2020 8.58 AM       NaN          NaN  ...               20
# 2    1-July-2020 9.30 PM      25.0          NaN  ...               25
# 3    1-July-2020 9.05 PM       NaN          NaN  ...               25
# 4    1-July-2020 7.38 PM       NaN          NaN  ...               20
# 5    1-July-2020 8.38 PM       NaN          NaN  ...               20
# 6    1-July-2020 8.38 PM      50.0          NaN  ...               20
# 7    1-July-2020 9.58 AM       NaN          NaN  ...               20
# 8    1-July-2020 8.30 PM      25.0          NaN  ...               25
# 9    1-July-2020 9.05 PM       NaN          NaN  ...               25
# 10   1-July-2020 8.38 PM       NaN          NaN  ...               20
# 11   2-July-2020 9.38 PM      50.0          NaN  ...               20
# 12   2-July-2020 8.58 AM      50.0          NaN  ...               20
# 13  2-July-2020 10.30 PM       NaN          NaN  ...               25
# 14   2-July-2020 9.05 PM      50.0          NaN  ...               25
# 16   2-July-2020 8.38 PM       NaN          NaN  ...               20
# 17   2-July-2020 8.38 PM       NaN          NaN  ...               20
# 18   2-July-2020 9.58 AM      50.0          NaN  ...               20
# 19   2-July-2020 9.58 AM      50.0          NaN  ...               20
# 20   2-July-2020 9.30 PM       NaN          NaN  ...               25
# 21   2-July-2020 9.05 PM      50.0          NaN  ...               25
# 22   2-July-2020 8.38 PM      50.0          NaN  ...               20
# 24   3-July-2020 9.38 PM      50.0          NaN  ...               20
# 26   3-July-2020 9.30 PM      25.0          NaN  ...               25
# 27   3-July-2020 9.05 PM       NaN          NaN  ...               25
# 28   3-July-2020 8.38 PM       NaN          NaN  ...               20
# 29   3-July-2020 8.38 PM      25.0          NaN  ...               20
# 30   3-July-2020 9.58 AM       NaN          NaN  ...               20
# 31   3-July-2020 8.30 PM      25.0          NaN  ...               25
# 32   3-July-2020 9.05 PM       NaN          NaN  ...               25
# 33   3-July-2020 8.38 PM       NaN          NaN  ...               20
# 34   4-July-2020 9.38 PM      25.0          NaN  ...               20
# 35   4-July-2020 7.38 PM      25.0          NaN  ...               20
# 36   4-July-2020 8.58 AM      25.0          NaN  ...               20
# 37  4-July-2020 10.30 PM       NaN          NaN  ...               25
# 38   4-July-2020 9.05 PM      25.0          NaN  ...               25
# 39   4-July-2020 8.38 PM       NaN          NaN  ...               20
# 40   4-July-2020 8.38 PM       NaN          NaN  ...               20
# 41   4-July-2020 9.58 AM      25.0          NaN  ...               20
# 42   4-July-2020 9.58 AM     -25.0          NaN  ...               20
# 43   4-July-2020 9.30 PM       NaN          NaN  ...               25
# 44   4-July-2020 9.05 PM      25.0          NaN  ...               25
# 45   4-July-2020 8.38 PM       NaN          NaN  ...               20
# 46   5-July-2020 9.38 PM       NaN          NaN  ...               20
# 47   5-July-2020 9.38 PM       NaN          NaN  ...               20
# 48   5-July-2020 8.58 AM       NaN          NaN  ...               20
# 49   5-July-2020 9.30 PM       NaN          NaN  ...               25
# 50   5-July-2020 9.05 PM       NaN          NaN  ...               25
# 51   5-July-2020 8.38 PM       NaN          NaN  ...               20
# 52   5-July-2020 8.38 PM       NaN          NaN  ...               20
# 53   5-July-2020 9.58 AM       NaN          NaN  ...               20
# 55   5-July-2020 9.58 AM       NaN          NaN  ...               20
# 56   5-July-2020 8.30 PM       NaN          NaN  ...               25
# 57   5-July-2020 9.05 PM       NaN          NaN  ...               25
# 58   5-July-2020 8.38 PM       NaN          NaN  ...               20
# 59   5-July-2020 8.38 PM       NaN          NaN  ...               20
#
#    Surge charges Packaging charges ST  Tip  PureVeg             Items  \
# 0            NaN                10  5  NaN        Y       PANEER;ROTI
# 1            NaN                10  5  5.0        N  DAL;CHICKEN;ROTI
# 2             10                10  5  5.0        Y       MIXVEG;RICE
# 3             10                10  5  NaN        N   CHICKEN;BIRYANI
# 4            NaN                10  5  NaN        Y          DAL;ROTI
# 5            NaN                10  5  NaN        Y          DAL;ROTI
# 6            NaN                10  5  NaN        Y       PANEER;ROTI
# 7            NaN                10  5  5.0        N  DAL;CHICKEN;ROTI
# 8             10                10  5  5.0        Y       MIXVEG;RICE
# 9             10                10  5  NaN        N   CHICKEN;BIRYANI
# 10           NaN                10  5  NaN        Y          DAL;ROTI
# 11           NaN                10  5  NaN        Y       PANEER;ROTI
# 12           NaN                10  5  5.0        N  DAL;CHICKEN;ROTI
# 13            10                10  5  5.0        Y       MIXVEG;RICE
# 14            10                10  5  NaN        N   CHICKEN;BIRYANI
# 16           NaN                10  5  NaN        Y          DAL;ROTI
# 17           NaN                10  5  NaN        Y       PANEER;ROTI
# 18           NaN                10  5  5.0        N  DAL;CHICKEN;ROTI
# 19           NaN                10  5  5.0        N  DAL;CHICKEN;ROTI
# 20            10                10  5  5.0        Y       MIXVEG;RICE
# 21            10                10  5  NaN        N   CHICKEN;BIRYANI
# 22           NaN                10  5  NaN        Y          DAL;ROTI
# 24           NaN                10  5  NaN        Y       PANEER;ROTI
# 26            10                10  5  5.0        Y       MIXVEG;RICE
# 27            10                10  5  NaN        N   CHICKEN;BIRYANI
# 28           NaN                10  5  NaN        Y          DAL;ROTI
# 29           NaN                10  5  NaN        Y       PANEER;ROTI
# 30           NaN                10  5  5.0        N  DAL;CHICKEN;ROTI
# 31            10                10  5  5.0        Y       MIXVEG;RICE
# 32            10                10  5  NaN        N   CHICKEN;BIRYANI
# 33           NaN                10  5  NaN        Y          DAL;ROTI
# 34           NaN                10  5  NaN        Y       PANEER;ROTI
# 35           NaN                10  5  NaN        Y       PANEER;ROTI
# 36           NaN                10  5  5.0        N  DAL;CHICKEN;ROTI
# 37            10                10  5  5.0        Y       MIXVEG;RICE
# 38            10                10  5  NaN        N   CHICKEN;BIRYANI
# 39           NaN                10  5  NaN        Y          DAL;ROTI
# 40           NaN                10  5  NaN        Y       PANEER;ROTI
# 41           NaN                10  5  5.0        N  DAL;CHICKEN;ROTI
# 42           NaN                10  5  5.0        N  DAL;CHICKEN;ROTI
# 43            10                10  5  5.0        Y       MIXVEG;RICE
# 44            10                10  5  NaN        N   CHICKEN;BIRYANI
# 45           NaN                10  5  NaN        Y          DAL;ROTI
# 46            20                10  5  NaN        Y       PANEER;ROTI
# 47            20                10  5  NaN        Y       PANEER;ROTI
# 48            20                10  5  5.0        N  DAL;CHICKEN;ROTI
# 49            20                10  5  5.0        Y       MIXVEG;RICE
# 50            20                10  5  NaN        N   CHICKEN;BIRYANI
# 51            20                10  5  NaN        Y          DAL;ROTI
# 52            20                10  5  NaN        Y       PANEER;ROTI
# 53           NaN                10  5  5.0        N  DAL;CHICKEN;ROTI
# 55           NaN                10  5  5.0        N  DAL;CHICKEN;ROTI
# 56            20                10  5  5.0        Y       MIXVEG;RICE
# 57            20                10  5  NaN        N   CHICKEN;BIRYANI
# 58            20                10  5  NaN        Y          DAL;ROTI
# 59            20                10  5  NaN        Y          DAL;ROTI
#
#    Membership Type Rating
# 0        BING  VEG    2.0
# 1        BONG  MIX    4.0
# 2        BING  VEG    0.0
# 3          NO  MIX    1.0
# 4          NO  VEG    1.0
# 5          NO  VEG    1.0
# 6        BING  VEG    2.0
# 7        BONG  MIX    4.0
# 8        BING  VEG    0.0
# 9          NO  MIX    1.0
# 10         NO  VEG    1.0
# 11       BING  VEG    4.0
# 12       BONG  MIX    4.0
# 13       BING  VEG    0.0
# 14         NO  MIX    4.0
# 16         NO  VEG    0.0
# 17       BING  VEG    2.0
# 18       BONG  MIX    3.0
# 19       BONG  MIX    3.0
# 20       BING  VEG    0.0
# 21         NO  MIX    3.0
# 22         NO  VEG    0.0
# 24       BING  VEG    3.0
# 26       BING  VEG    0.0
# 27         NO  MIX    2.0
# 28         NO  VEG    2.0
# 29       BING  VEG    3.0
# 30       BONG  MIX    5.0
# 31       BING  VEG    0.0
# 32         NO  MIX    3.0
# 33         NO  VEG    3.0
# 34       BING  VEG    5.0
# 35       BING  VEG    5.0
# 36       BONG  MIX    5.0
# 37       BING  VEG    0.0
# 38         NO  MIX    5.0
# 39         NO  VEG    0.0
# 40       BING  VEG    3.0
# 41       BONG  MIX    4.0
# 42       BONG  MIX    4.0
# 43       BING  VEG    0.0
# 44         NO  MIX    3.0
# 45         NO  VEG    0.0
# 46       BING  VEG    NaN
# 47       BING  VEG    3.0
# 48       BONG  MIX    5.0
# 49       BING  VEG    0.0
# 50       BING  MIX    3.0
# 51       BING  VEG    3.0
# 52       BING  VEG    4.0
# 53       BONG  MIX    5.0
# 55       BONG  MIX    NaN
# 56       BING  VEG    0.0
# 57       BING  MIX    3.0
# 58       BING  VEG    3.0
# 59       BING  VEG    3.0
#
# [56 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 0 to 59
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 56 non-null     float64
#  1   Provider           0 non-null      float64
#  2   DateTime           58 non-null     object
#  3   Distance           57 non-null     float64
#  4   Status             57 non-null     object
#  5   Cost               58 non-null     object
#  6   PromoCode          35 non-null     object
#  7   Delivery Time      57 non-null     object
#  8   Discount           23 non-null     float64
#  9   Paid amount        1 non-null      float64
#  10  Payment mode       57 non-null     object
#  11  Delivery charges   58 non-null     object
#  12  Surge charges      28 non-null     object
#  13  Packaging charges  58 non-null     object
#  14  ST                 58 non-null     object
#  15  Tip                24 non-null     float64
#  16  PureVeg            57 non-null     object
#  17  Items              57 non-null     object
#  18  Membership         57 non-null     object
#  19  Type               57 non-null     object
#  20  Rating             55 non-null     float64
# dtypes: float64(7), object(14)
# memory usage: 12.0+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58 entries, 0 to 59
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 56 non-null     float64
#  1   Provider           0 non-null      float64
#  2   DateTime           58 non-null     object
#  3   Distance           57 non-null     float64
#  4   Status             57 non-null     object
#  5   Cost               58 non-null     object
#  6   PromoCode          35 non-null     object
#  7   Delivery Time      57 non-null     object
#  8   Discount           23 non-null     float64
#  9   Paid amount        1 non-null      float64
#  10  Payment mode       57 non-null     object
#  11  Delivery charges   58 non-null     object
#  12  Surge charges      28 non-null     object
#  13  Packaging charges  58 non-null     object
#  14  ST                 58 non-null     object
#  15  Tip                24 non-null     float64
#  16  PureVeg            57 non-null     object
#  17  Items              57 non-null     object
#  18  Membership         57 non-null     object
#  19  Type               57 non-null     object
#  20  Rating             55 non-null     float64
# dtypes: float64(7), object(14)
# memory usage: 12.0+ KB

# %%
df.isna().sum() #check na value
df.Rating.value_counts()
# Out:
# 3.0    15
# 0.0    14
# 4.0     8
# 5.0     8
# 2.0     5
# 1.0     5
# Name: Rating, dtype: int64

# %%
def reformat_col(x):
    return x.strip().replace(' ', '_').replace('/', '_')

# %%
df.rename(columns = reformat_col, inplace=True)

# %%
df.head();

# %%
df['time_difference'] = df['Delivery_Time'] - df['DateTime']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:163, in _na_arithmetic_op(left, right, op, is_cmp)
#     162 try:
# --> 163     result = func(left, right)
#     164 except TypeError:
#
# File ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:239, in evaluate(op, a, b, use_numexpr)
#     237     if use_numexpr:
#     238         # error: "None" not callable
# --> 239         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:128, in _evaluate_numexpr(op, op_str, a, b)
#     127 if result is None:
# --> 128     result = _evaluate_standard(op, op_str, a, b)
#     130 return result
#
# File ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:69, in _evaluate_standard(op, op_str, a, b)
#      68     _store_test_result(False)
# ---> 69 return op(a, b)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
# ----> 1 df['time_difference'] = df['Delivery_Time'] - df['DateTime']
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:108, in OpsMixin.__sub__(self, other)
#     106 @unpack_zerodim_and_defer("__sub__")
#     107 def __sub__(self, other):
# --> 108     return self._arith_method(other, operator.sub)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:5639, in Series._arith_method(self, other, op)
#    5637 def _arith_method(self, other, op):
#    5638     self, other = ops.align_method_SERIES(self, other)
# -> 5639     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~\anaconda3\lib\site-packages\pandas\core\base.py:1295, in IndexOpsMixin._arith_method(self, other, op)
#    1292 rvalues = ensure_wrapped_if_datetimelike(rvalues)
#    1294 with np.errstate(all="ignore"):
# -> 1295     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1297 return self._construct_result(result, name=res_name)
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:222, in arithmetic_op(left, right, op)
#     217 else:
#     218     # TODO we should handle EAs consistently and move this check before the if/else
#     219     # (https://github.com/pandas-dev/pandas/issues/41165)
#     220     _bool_arith_check(op, left, right)
# --> 222     res_values = _na_arithmetic_op(left, right, op)
#     224 return res_values
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:170, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 except TypeError:
#     165     if not is_cmp and (is_object_dtype(left.dtype) or is_object_dtype(right)):
#     166         # For object dtype, fallback to a masked operation (only operating
#     167         #  on the non-missing values)
#     168         # Don't do this for comparisons, as that will handle complex numbers
#     169         #  incorrectly, see GH#32047
# --> 170         result = _masked_arith_op(left, right, op)
#     171     else:
#     172         raise
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:108, in _masked_arith_op(x, y, op)
#     106     # See GH#5284, GH#5035, GH#19448 for historical reference
#     107     if mask.any():
# --> 108         result[mask] = op(xrav[mask], yrav[mask])
#     110 else:
#     111     if not is_scalar(y):
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
